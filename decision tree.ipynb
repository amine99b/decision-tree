# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv'
    
titanic = pd.read_csv(url)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
def preprocess_data(new_data):
    new_data['Age'].fillna(new_data['Age'].mean(),inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
df=preprocess_data(titanic)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ..                                                 ...  ...        ...    ...
# 886                              Montvila, Rev. Juozas    1  27.000000      0
# 887                       Graham, Miss. Margaret Edith    0  19.000000      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    0  29.699118      1
# 889                              Behr, Mr. Karl Howell    1  26.000000      0
# 890                                Dooley, Mr. Patrick    1  32.000000      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500    G6        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250    G6        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500    G6        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000    G6        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500    G6        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500    G6        Q
#
# [891 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier

# %%
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked"], axis=1)
y= data["Survived"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

# %%
tree = tree.DecisionTreeClassifier()  
tree.fit(x_train, y_train)   
y_pred=tree.predict(x_test)  
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7374301675977654

# %%
clf = DecisionTreeClassifier(max_depth=4, min_samples_split=10, random_state=42)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_split=10, random_state=42)

# %%
plot_tree(clf)
# Out:
# [Text(0.45689655172413796, 0.9, 'X[2] <= 0.5\ngini = 0.477\nsamples = 712\nvalue = [432, 280]'),
#  Text(0.1896551724137931, 0.7, 'X[1] <= 2.5\ngini = 0.388\nsamples = 258\nvalue = [68, 190]'),
#  Text(0.06896551724137931, 0.5, 'X[3] <= 3.0\ngini = 0.11\nsamples = 137\nvalue = [8, 129]'),
#  Text(0.034482758620689655, 0.3, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10344827586206896, 0.3, 'X[6] <= 26.125\ngini = 0.098\nsamples = 135\nvalue = [7, 128]'),
#  Text(0.06896551724137931, 0.1, 'gini = 0.211\nsamples = 50\nvalue = [6, 44]'),
#  Text(0.13793103448275862, 0.1, 'gini = 0.023\nsamples = 85\nvalue = [1, 84]'),
#  Text(0.3103448275862069, 0.5, 'X[6] <= 24.808\ngini = 0.5\nsamples = 121\nvalue = [60, 61]'),
#  Text(0.2413793103448276, 0.3, 'X[3] <= 29.85\ngini = 0.479\nsamples = 98\nvalue = [39, 59]'),
#  Text(0.20689655172413793, 0.1, 'gini = 0.45\nsamples = 82\nvalue = [28, 54]'),
#  Text(0.27586206896551724, 0.1, 'gini = 0.43\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.3793103448275862, 0.3, 'X[0] <= 49.0\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.3448275862068966, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41379310344827586, 0.1, 'gini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.7241379310344828, 0.7, 'X[1] <= 1.5\ngini = 0.318\nsamples = 454\nvalue = [364, 90]'),
#  Text(0.5862068965517241, 0.5, 'X[0] <= 355.5\ngini = 0.465\nsamples = 98\nvalue = [62, 36]'),
#  Text(0.5172413793103449, 0.3, 'X[0] <= 27.5\ngini = 0.305\nsamples = 32\nvalue = [26, 6]'),
#  Text(0.4827586206896552, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5517241379310345, 0.1, 'gini = 0.271\nsamples = 31\nvalue = [26, 5]'),
#  Text(0.6551724137931034, 0.3, 'X[6] <= 26.144\ngini = 0.496\nsamples = 66\nvalue = [36, 30]'),
#  Text(0.6206896551724138, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6896551724137931, 0.1, 'gini = 0.5\nsamples = 59\nvalue = [29, 30]'),
#  Text(0.8620689655172413, 0.5, 'X[3] <= 13.0\ngini = 0.257\nsamples = 356\nvalue = [302, 54]'),
#  Text(0.7931034482758621, 0.3, 'X[4] <= 2.5\ngini = 0.499\nsamples = 25\nvalue = [12, 13]'),
#  Text(0.7586206896551724, 0.1, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.8275862068965517, 0.1, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.9310344827586207, 0.3, 'X[6] <= 51.698\ngini = 0.217\nsamples = 331\nvalue = [290, 41]'),
#  Text(0.896551724137931, 0.1, 'gini = 0.206\nsamples = 317\nvalue = [280, 37]'),
#  Text(0.9655172413793104, 0.1, 'gini = 0.408\nsamples = 14\nvalue = [10, 4]')]

# %%
y_pred = clf.predict(x_test)

# %%
accuracy = clf.score(x_test, y_test)
print("Accuracy (Decision Tree):", accuracy)
# Out:
# Accuracy (Decision Tree): 0.8212290502793296

# %%
rfc = RandomForestClassifier(n_estimators=50, max_depth=4, min_samples_split=10, random_state=42)
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4, min_samples_split=10, n_estimators=50,
#                        random_state=42)

# %%
y_pred = rfc.predict(x_test)

# %%
accuracy = rfc.score(x_test, y_test)
print("Accuracy (Random Forest):", accuracy)
# Out:
# Accuracy (Random Forest): 0.8603351955307262
